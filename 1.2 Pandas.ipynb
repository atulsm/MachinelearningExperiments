# %%
#consistes of series
#group of series form dataframe

import pandas as pd
s1 = pd.Series(data=[1,2,3,4,5],index=['a','b','c','d','e'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2 = pd.Series(data=[11,22,33,44,55],index=['a','b','c','d','e'])

# %%
s2
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %%
s1+s2
# Out:
# a    12
# b    24
# c    36
# d    48
# e    60
# dtype: int64

# %%
s1['a']
# Out:
# 1

# %%
s1['a':'d']
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s1[0:3]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.DataFrame({'A':s1,'B':s2})
# Out:
#    A   B
# a  1  11
# b  2  22
# c  3  33
# d  4  44
# e  5  55

# %%
pd.DataFrame({'A':s1,'B':s2}, index=['a','b','g'])
# Out:
#      A     B
# a  1.0  11.0
# b  2.0  22.0
# g  NaN   NaN

# %%
pd.DataFrame([s1,s2])
# Out:
#     a   b   c   d   e
# 0   1   2   3   4   5
# 1  11  22  33  44  55

# %%
s3 = pd.Series(data=[111,222],index=['a','b'])

# %%
s3
# Out:
# a    111
# b    222
# dtype: int64

# %%
df = pd.DataFrame({'A':s1,'B':s2, 'C':s3})

# %%
df
# Out:
#    A   B      C
# a  1  11  111.0
# b  2  22  222.0
# c  3  33    NaN
# d  4  44    NaN
# e  5  55    NaN

# %%
tent_data = pd.read_csv('data\house_rental_data.csv')

# %%
tent_data.describe()
# Out:
#        Unnamed: 0         Sqft       Floor  TotalFloor     Bedroom  \
# count  645.000000   645.000000  645.000000  645.000000  645.000000
# mean   325.159690  1527.656260    5.939535   10.855814    2.837209
# std    187.312152   767.386531    3.884721    4.996208    1.010740
# min      1.000000   359.358000    1.000000    1.000000    1.000000
# 25%    164.000000   925.080000    3.000000    7.000000    2.000000
# 50%    326.000000  1423.200000    5.000000   12.000000    3.000000
# 75%    487.000000  1892.856000    8.000000   14.000000    4.000000
# max    648.000000  5856.468000   22.000000   38.000000    7.000000
#
#        Living.Room    Bathroom          Price
# count   645.000000  645.000000     645.000000
# mean      1.813953    1.810853   61986.823256
# std       0.462364    0.683574   35635.091007
# min       0.000000    0.000000    6100.000000
# 25%       2.000000    1.000000   39000.000000
# 50%       2.000000    2.000000   50000.000000
# 75%       2.000000    2.000000   75000.000000
# max       4.000000    5.000000  250000.000000

# %%
tent_data.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
emp_data = pd.read_csv('data\HR_comma_sep.csv')

# %%
emp_data.head()
#descriptive statistics
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
emp_data.describe()
#inferential staistics
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
emp_data.rename(columns={'sales':'dept'},inplace=True)

# %%
emp_data.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %% [markdown]
# emp_data.head()

# %%
emp_data.dept.value_counts()
#nominal data
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: dept, dtype: int64

# %%
emp_data.salary.value_counts()
#ordinal data => values have a relation
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
emp_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
#first check if data is balanced is not
#question. to predict if a person will leave or not
#because we have a column/variable left=0/1

emp_data.left.plot()

# %%
emp_data.left.mean()
# Out:
# 0.2380825388359224

# %%
#target variable/response variable/dependent variable => left
#All other variables => Feature vector/ Independent variable

#Usually dataset is represented as (vector(X), Y)
#Vector(X) => Feature vector

# %%
#need to heck if there are any lurking variables , which is not considered in X, or Y

# %%
#mean is impacted by outliers

#mean = sum/count
#median => Sort value, take middle
#mode => Max occuring value

# %%
emp_data.iloc[5:15]
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# 11                0.11             0.81               6                   305
# 12                0.84             0.92               4                   234
# 13                0.41             0.55               2                   148
# 14                0.36             0.56               2                   137
#
#     time_spend_company  Work_accident  left  promotion_last_5years   dept  \
# 5                    3              0     1                      0  sales
# 6                    4              0     1                      0  sales
# 7                    5              0     1                      0  sales
# 8                    5              0     1                      0  sales
# 9                    3              0     1                      0  sales
# 10                   3              0     1                      0  sales
# 11                   4              0     1                      0  sales
# 12                   5              0     1                      0  sales
# 13                   3              0     1                      0  sales
# 14                   3              0     1                      0  sales
#
#    salary
# 5     low
# 6     low
# 7     low
# 8     low
# 9     low
# 10    low
# 11    low
# 12    low
# 13    low
# 14    low

# %%
cols = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
        ,'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Salary']
adult = pd.read_csv('data/adult.data.txt', header=None, names=cols)

# %%
adult.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
target_data = adult['Salary']

# %%
feature_data = adult.drop(['Salary'], axis=1)

# %%
feature_data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0          2174             0              40   United-States
# 1             0             0              13   United-States
# 2             0             0              40   United-States
# 3             0             0              40   United-States
# 4             0             0              40            Cuba

# %%
target_data.head()
# Out:
# 0     <=50K
# 1     <=50K
# 2     <=50K
# 3     <=50K
# 4     <=50K
# Name: Salary, dtype: object

# %%
adult1 = adult.set_index('age')

# %%
adult1.head()
# Out:
#              workclass  fnlwgt   education  education-num  \
# age
# 39           State-gov   77516   Bachelors             13
# 50    Self-emp-not-inc   83311   Bachelors             13
# 38             Private  215646     HS-grad              9
# 53             Private  234721        11th              7
# 28             Private  338409   Bachelors             13
#
#           marital-status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28    Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#      capital-gain  capital-loss  hours-per-week  native-country  Salary
# age
# 39           2174             0              40   United-States   <=50K
# 50              0             0              13   United-States   <=50K
# 38              0             0              40   United-States   <=50K
# 53              0             0              40   United-States   <=50K
# 28              0             0              40            Cuba   <=50K

# %%
adult[adult.age == 20]
# Out:
#        age     workclass  fnlwgt      education  education-num  \
# 31      20       Private  266015   Some-college             10
# 103     20       Private  188300   Some-college             10
# 126     20       Private  111697   Some-college             10
# 138     20       Private   34310   Some-college             10
# 243     20             ?  119156   Some-college             10
# 256     20       Private  117789        HS-grad              9
# 375     20     Local-gov  350845   Some-college             10
# 397     20             ?  137300        HS-grad              9
# 400     20       Private  416103   Some-college             10
# 420     20       Private   61777   Some-college             10
# 445     20       Private  298227   Some-college             10
# 448     20       Private  146538        HS-grad              9
# 496     20       Private  262749   Some-college             10
# 517     20             ?  214635   Some-college             10
# 565     20       Private   27337        HS-grad              9
# 650     20       Private  130959   Some-college             10
# 664     20       Private   81145   Some-college             10
# 668     20             ?  114746           11th              7
# 693     20       Private  316702   Some-college             10
# 727     20       Private  299047   Some-college             10
# 809     20       Private  138768        HS-grad              9
# 944     20       Private  241752        HS-grad              9
# 965     20       Private  323573        HS-grad              9
# 1000    20       Private  148294   Some-college             10
# 1031    20     State-gov  223515     Assoc-acdm             12
# 1048    20       Private   74631   Some-college             10
# 1125    20       Private  117606      Assoc-voc             11
# 1141    20       Private  230891   Some-college             10
# 1159    20       Private  275691        HS-grad              9
# 1173    20       Private  411862      Assoc-voc             11
# ...    ...           ...     ...            ...            ...
# 30791   20       Private  130840           10th              6
# 30793   20       Private  334105   Some-college             10
# 30881   20       Private  333505        HS-grad              9
# 30894   20       Private  303565   Some-college             10
# 30907   20       Private  168187   Some-college             10
# 31052   20       Private  190227        Masters             14
# 31156   20       Private  381357            9th              5
# 31183   20       Private  218962        HS-grad              9
# 31265   20       Private  162688      Assoc-voc             11
# 31279   20             ?   95989   Some-college             10
# 31296   20     State-gov  214542   Some-college             10
# 31374   20       Private   63210        HS-grad              9
# 31422   20       Private  163665   Some-college             10
# 31490   20       Private  224640     Assoc-acdm             12
# 31494   20       Private  105479   Some-college             10
# 31605   20             ?  369678           12th              8
# 31698   20             ?  189203     Assoc-acdm             12
# 31753   20             ?   71788   Some-college             10
# 31769   20       Private  157332   Some-college             10
# 31804   20   Federal-gov  347935   Some-college             10
# 32030   20       Private  344394   Some-college             10
# 32045   20       Private  184045   Some-college             10
# 32108   20       Private   86143   Some-college             10
# 32168   20       Private  200153        HS-grad              9
# 32275   20             ?   99891   Some-college             10
# 32387   20       Private  176321   Some-college             10
# 32406   20       Private  234640   Some-college             10
# 32417   20       Private  227778   Some-college             10
# 32426   20             ?  203992        HS-grad              9
# 32512   20       Private  270436        HS-grad              9
#
#                marital-status          occupation     relationship  \
# 31              Never-married               Sales        Own-child
# 103             Never-married        Tech-support        Own-child
# 126             Never-married        Adm-clerical        Own-child
# 138             Never-married               Sales        Own-child
# 243             Never-married                   ?        Own-child
# 256             Never-married       Other-service        Own-child
# 375             Never-married        Adm-clerical        Own-child
# 397             Never-married                   ?   Other-relative
# 400             Never-married   Handlers-cleaners        Own-child
# 420        Married-civ-spouse               Sales          Husband
# 445             Never-married               Sales    Not-in-family
# 448        Married-civ-spouse   Machine-op-inspct          Husband
# 496             Never-married   Machine-op-inspct        Own-child
# 517             Never-married                   ?        Own-child
# 565             Never-married   Handlers-cleaners        Own-child
# 650             Never-married       Other-service        Own-child
# 664             Never-married               Sales    Not-in-family
# 668     Married-spouse-absent                   ?        Own-child
# 693             Never-married      Prof-specialty        Own-child
# 727             Never-married       Other-service    Not-in-family
# 809             Never-married    Transport-moving        Own-child
# 944        Married-civ-spouse   Machine-op-inspct          Husband
# 965             Never-married       Other-service        Own-child
# 1000            Never-married       Other-service        Own-child
# 1031            Never-married       Other-service        Own-child
# 1048            Never-married               Sales    Not-in-family
# 1125            Never-married        Adm-clerical        Own-child
# 1141            Never-married               Sales    Not-in-family
# 1159            Never-married   Handlers-cleaners        Own-child
# 1173            Never-married       Other-service    Not-in-family
# ...                       ...                 ...              ...
# 30791           Never-married   Handlers-cleaners        Own-child
# 30793           Never-married       Other-service        Own-child
# 30881           Never-married        Adm-clerical        Own-child
# 30894           Never-married   Handlers-cleaners        Own-child
# 30907           Never-married       Other-service   Other-relative
# 31052           Never-married     Exec-managerial        Own-child
# 31156           Never-married   Handlers-cleaners        Own-child
# 31183           Never-married   Machine-op-inspct    Not-in-family
# 31265           Never-married       Other-service        Own-child
# 31279           Never-married                   ?        Own-child
# 31296           Never-married      Prof-specialty        Own-child
# 31374           Never-married   Handlers-cleaners        Own-child
# 31422           Never-married    Transport-moving        Own-child
# 31490           Never-married     Exec-managerial        Own-child
# 31494           Never-married               Sales    Not-in-family
# 31605           Never-married                   ?    Not-in-family
# 31698           Never-married                   ?    Not-in-family
# 31753           Never-married                   ?        Own-child
# 31769           Never-married        Adm-clerical        Own-child
# 31804           Never-married     Protective-serv        Own-child
# 32030           Never-married       Other-service    Not-in-family
# 32045           Never-married               Sales        Unmarried
# 32108           Never-married       Other-service   Other-relative
# 32168           Never-married       Other-service        Own-child
# 32275           Never-married                   ?        Own-child
# 32387           Never-married        Adm-clerical   Other-relative
# 32406           Never-married        Adm-clerical        Own-child
# 32417           Never-married               Sales    Not-in-family
# 32426           Never-married                   ?        Own-child
# 32512           Never-married   Machine-op-inspct        Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 31                   Black     Male             0             0
# 103                  White   Female             0             0
# 126                  White   Female             0          1719
# 138                  White     Male             0             0
# 243                  White     Male             0             0
# 256                  White   Female             0             0
# 375                  White   Female             0             0
# 397                  White   Female             0             0
# 400                  White     Male             0             0
# 420                  White     Male             0             0
# 445                  White     Male             0             0
# 448                  White     Male             0             0
# 496                  White     Male             0             0
# 517                  White     Male             0             0
# 565     Amer-Indian-Eskimo     Male             0             0
# 650                  White     Male             0             0
# 664                  White   Female             0             0
# 668     Asian-Pac-Islander   Female             0          1762
# 693                  White     Male             0             0
# 727                  White   Female             0             0
# 809                  White     Male             0             0
# 944                  White     Male             0             0
# 965                  White   Female             0             0
# 1000                 White     Male             0             0
# 1031                 White     Male             0          1719
# 1048                 White   Female             0             0
# 1125                 White   Female             0             0
# 1141                 White     Male             0             0
# 1159                 White     Male             0             0
# 1173                 White     Male             0             0
# ...                    ...      ...           ...           ...
# 30791                White     Male             0             0
# 30793                White   Female             0             0
# 30881                White     Male             0             0
# 30894                Black     Male             0             0
# 30907                White   Female          4416             0
# 31052                White     Male             0             0
# 31156                White     Male             0             0
# 31183                White     Male             0             0
# 31265                White     Male             0             0
# 31279                White   Female             0             0
# 31296                White     Male             0             0
# 31374                White     Male             0             0
# 31422                White   Female             0             0
# 31490                White   Female             0             0
# 31494                White   Female             0             0
# 31605                Other     Male             0          1602
# 31698                White     Male             0             0
# 31753                White   Female             0             0
# 31769                White   Female             0             0
# 31804                Black     Male             0             0
# 32030                White   Female             0             0
# 32045                Black   Female             0             0
# 32108   Asian-Pac-Islander     Male             0             0
# 32168                White   Female             0             0
# 32275                White   Female             0             0
# 32387                White   Female             0             0
# 32406                White   Female             0             0
# 32417                White   Female             0             0
# 32426                White     Male             0             0
# 32512                White     Male             0             0
#
#        hours-per-week  native-country  Salary
# 31                 44   United-States   <=50K
# 103                40   United-States   <=50K
# 126                28   United-States   <=50K
# 138                20   United-States   <=50K
# 243                20   United-States   <=50K
# 256                40   United-States   <=50K
# 375                10   United-States   <=50K
# 397                35   United-States   <=50K
# 400                40   United-States   <=50K
# 420                30   United-States   <=50K
# 445                35   United-States   <=50K
# 448                40   United-States   <=50K
# 496                40   United-States   <=50K
# 517                24   United-States   <=50K
# 565                48   United-States   <=50K
# 650                20   United-States   <=50K
# 664                25   United-States   <=50K
# 668                40           South   <=50K
# 693                20   United-States   <=50K
# 727                20   United-States   <=50K
# 809                30   United-States   <=50K
# 944                40   United-States   <=50K
# 965                20   United-States   <=50K
# 1000               40   United-States   <=50K
# 1031               20   United-States   <=50K
# 1048               50   United-States   <=50K
# 1125               40   United-States   <=50K
# 1141               45   United-States   <=50K
# 1159               28   United-States   <=50K
# 1173               30   United-States   <=50K
# ...               ...             ...     ...
# 30791              40   United-States   <=50K
# 30793              10   United-States   <=50K
# 30881              30       Nicaragua   <=50K
# 30894              40         Germany   <=50K
# 30907              25   United-States   <=50K
# 31052              25   United-States   <=50K
# 31156              28   United-States   <=50K
# 31183              40   United-States   <=50K
# 31265              40   United-States   <=50K
# 31279              40   United-States   <=50K
# 31296              40   United-States   <=50K
# 31374              15   United-States   <=50K
# 31422              17   United-States   <=50K
# 31490              40   United-States   <=50K
# 31494              25   United-States   <=50K
# 31605              40   United-States   <=50K
# 31698              20   United-States   <=50K
# 31753              18   United-States   <=50K
# 31769              25   United-States   <=50K
# 31804              40   United-States   <=50K
# 32030              30   United-States   <=50K
# 32045              30   United-States   <=50K
# 32108              30   United-States   <=50K
# 32168              38   United-States   <=50K
# 32275              30   United-States   <=50K
# 32387              20   United-States   <=50K
# 32406              40   United-States   <=50K
# 32417              56   United-States   <=50K
# 32426              40   United-States   <=50K
# 32512              40   United-States   <=50K
#
# [753 rows x 15 columns]

# %%
adult1[adult1.index==20]
# Out:
#         workclass  fnlwgt      education  education-num  \
# age
# 20        Private  266015   Some-college             10
# 20        Private  188300   Some-college             10
# 20        Private  111697   Some-college             10
# 20        Private   34310   Some-college             10
# 20              ?  119156   Some-college             10
# 20        Private  117789        HS-grad              9
# 20      Local-gov  350845   Some-college             10
# 20              ?  137300        HS-grad              9
# 20        Private  416103   Some-college             10
# 20        Private   61777   Some-college             10
# 20        Private  298227   Some-college             10
# 20        Private  146538        HS-grad              9
# 20        Private  262749   Some-college             10
# 20              ?  214635   Some-college             10
# 20        Private   27337        HS-grad              9
# 20        Private  130959   Some-college             10
# 20        Private   81145   Some-college             10
# 20              ?  114746           11th              7
# 20        Private  316702   Some-college             10
# 20        Private  299047   Some-college             10
# 20        Private  138768        HS-grad              9
# 20        Private  241752        HS-grad              9
# 20        Private  323573        HS-grad              9
# 20        Private  148294   Some-college             10
# 20      State-gov  223515     Assoc-acdm             12
# 20        Private   74631   Some-college             10
# 20        Private  117606      Assoc-voc             11
# 20        Private  230891   Some-college             10
# 20        Private  275691        HS-grad              9
# 20        Private  411862      Assoc-voc             11
# ..            ...     ...            ...            ...
# 20        Private  130840           10th              6
# 20        Private  334105   Some-college             10
# 20        Private  333505        HS-grad              9
# 20        Private  303565   Some-college             10
# 20        Private  168187   Some-college             10
# 20        Private  190227        Masters             14
# 20        Private  381357            9th              5
# 20        Private  218962        HS-grad              9
# 20        Private  162688      Assoc-voc             11
# 20              ?   95989   Some-college             10
# 20      State-gov  214542   Some-college             10
# 20        Private   63210        HS-grad              9
# 20        Private  163665   Some-college             10
# 20        Private  224640     Assoc-acdm             12
# 20        Private  105479   Some-college             10
# 20              ?  369678           12th              8
# 20              ?  189203     Assoc-acdm             12
# 20              ?   71788   Some-college             10
# 20        Private  157332   Some-college             10
# 20    Federal-gov  347935   Some-college             10
# 20        Private  344394   Some-college             10
# 20        Private  184045   Some-college             10
# 20        Private   86143   Some-college             10
# 20        Private  200153        HS-grad              9
# 20              ?   99891   Some-college             10
# 20        Private  176321   Some-college             10
# 20        Private  234640   Some-college             10
# 20        Private  227778   Some-college             10
# 20              ?  203992        HS-grad              9
# 20        Private  270436        HS-grad              9
#
#              marital-status          occupation     relationship  \
# age
# 20            Never-married               Sales        Own-child
# 20            Never-married        Tech-support        Own-child
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married               Sales        Own-child
# 20            Never-married                   ?        Own-child
# 20            Never-married       Other-service        Own-child
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married                   ?   Other-relative
# 20            Never-married   Handlers-cleaners        Own-child
# 20       Married-civ-spouse               Sales          Husband
# 20            Never-married               Sales    Not-in-family
# 20       Married-civ-spouse   Machine-op-inspct          Husband
# 20            Never-married   Machine-op-inspct        Own-child
# 20            Never-married                   ?        Own-child
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married       Other-service        Own-child
# 20            Never-married               Sales    Not-in-family
# 20    Married-spouse-absent                   ?        Own-child
# 20            Never-married      Prof-specialty        Own-child
# 20            Never-married       Other-service    Not-in-family
# 20            Never-married    Transport-moving        Own-child
# 20       Married-civ-spouse   Machine-op-inspct          Husband
# 20            Never-married       Other-service        Own-child
# 20            Never-married       Other-service        Own-child
# 20            Never-married       Other-service        Own-child
# 20            Never-married               Sales    Not-in-family
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married               Sales    Not-in-family
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married       Other-service    Not-in-family
# ..                      ...                 ...              ...
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married       Other-service        Own-child
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married       Other-service   Other-relative
# 20            Never-married     Exec-managerial        Own-child
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married   Machine-op-inspct    Not-in-family
# 20            Never-married       Other-service        Own-child
# 20            Never-married                   ?        Own-child
# 20            Never-married      Prof-specialty        Own-child
# 20            Never-married   Handlers-cleaners        Own-child
# 20            Never-married    Transport-moving        Own-child
# 20            Never-married     Exec-managerial        Own-child
# 20            Never-married               Sales    Not-in-family
# 20            Never-married                   ?    Not-in-family
# 20            Never-married                   ?    Not-in-family
# 20            Never-married                   ?        Own-child
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married     Protective-serv        Own-child
# 20            Never-married       Other-service    Not-in-family
# 20            Never-married               Sales        Unmarried
# 20            Never-married       Other-service   Other-relative
# 20            Never-married       Other-service        Own-child
# 20            Never-married                   ?        Own-child
# 20            Never-married        Adm-clerical   Other-relative
# 20            Never-married        Adm-clerical        Own-child
# 20            Never-married               Sales    Not-in-family
# 20            Never-married                   ?        Own-child
# 20            Never-married   Machine-op-inspct        Own-child
#
#                     race      sex  capital-gain  capital-loss  hours-per-week  \
# age
# 20                 Black     Male             0             0              44
# 20                 White   Female             0             0              40
# 20                 White   Female             0          1719              28
# 20                 White     Male             0             0              20
# 20                 White     Male             0             0              20
# 20                 White   Female             0             0              40
# 20                 White   Female             0             0              10
# 20                 White   Female             0             0              35
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              30
# 20                 White     Male             0             0              35
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              24
# 20    Amer-Indian-Eskimo     Male             0             0              48
# 20                 White     Male             0             0              20
# 20                 White   Female             0             0              25
# 20    Asian-Pac-Islander   Female             0          1762              40
# 20                 White     Male             0             0              20
# 20                 White   Female             0             0              20
# 20                 White     Male             0             0              30
# 20                 White     Male             0             0              40
# 20                 White   Female             0             0              20
# 20                 White     Male             0             0              40
# 20                 White     Male             0          1719              20
# 20                 White   Female             0             0              50
# 20                 White   Female             0             0              40
# 20                 White     Male             0             0              45
# 20                 White     Male             0             0              28
# 20                 White     Male             0             0              30
# ..                   ...      ...           ...           ...             ...
# 20                 White     Male             0             0              40
# 20                 White   Female             0             0              10
# 20                 White     Male             0             0              30
# 20                 Black     Male             0             0              40
# 20                 White   Female          4416             0              25
# 20                 White     Male             0             0              25
# 20                 White     Male             0             0              28
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              40
# 20                 White   Female             0             0              40
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              15
# 20                 White   Female             0             0              17
# 20                 White   Female             0             0              40
# 20                 White   Female             0             0              25
# 20                 Other     Male             0          1602              40
# 20                 White     Male             0             0              20
# 20                 White   Female             0             0              18
# 20                 White   Female             0             0              25
# 20                 Black     Male             0             0              40
# 20                 White   Female             0             0              30
# 20                 Black   Female             0             0              30
# 20    Asian-Pac-Islander     Male             0             0              30
# 20                 White   Female             0             0              38
# 20                 White   Female             0             0              30
# 20                 White   Female             0             0              20
# 20                 White   Female             0             0              40
# 20                 White   Female             0             0              56
# 20                 White     Male             0             0              40
# 20                 White     Male             0             0              40
#
#      native-country  Salary
# age
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20            South   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# ..              ...     ...
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20        Nicaragua   <=50K
# 20          Germany   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
# 20    United-States   <=50K
#
# [753 rows x 14 columns]

# %%
adult.iloc[0]['marital-status']
#additional space. We have to trim
# Out:
# ' Never-married'

# %%
adult['marital-status'] = adult['marital-status'].str.strip()

# %%
adult.iloc[0]['marital-status']
# Out:
# 'Never-married'

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#        marital-status          occupation    relationship    race      sex  \
# 0       Never-married        Adm-clerical   Not-in-family   White     Male
# 1  Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2            Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3  Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4  Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Salary  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#         marital-staus
# 0       Never-married
# 1  Married-civ-spouse
# 2            Divorced
# 3  Married-civ-spouse
# 4  Married-civ-spouse

# %%
adult = adult.drop('marital-staus', axis=1)

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#        marital-status          occupation    relationship    race      sex  \
# 0       Never-married        Adm-clerical   Not-in-family   White     Male
# 1  Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2            Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3  Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4  Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Salary
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
adult.iat[0,2]
# Out:
# 77516

# %%
adult.at[1,'education']
# Out:
# ' Bachelors'

# %%
adult.loc[1:3]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
#
#        marital-status          occupation    relationship    race    sex  \
# 1  Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2            Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3  Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  Salary
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K

# %%
adult.loc[adult['capital-loss'] > 0]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 23      43            Private  117037           11th              7
# 32      45            Private  386940      Bachelors             13
# 52      47            Private   51835    Prof-school             15
# 93      30            Private  117747        HS-grad              9
# 96      48   Self-emp-not-inc  191277      Doctorate             16
# 112     56   Self-emp-not-inc  335605        HS-grad              9
# 126     20            Private  111697   Some-college             10
# 131     24            Private   43323        HS-grad              9
# 143     45            Private  196584      Assoc-voc             11
# 148     64            Private  181232           11th              7
# 157     71   Self-emp-not-inc  494223   Some-college             10
# 170     27            Private  124953        HS-grad              9
# 172     51            Private   96062   Some-college             10
# 200     26            Private  397317        Masters             14
# 203     42          Local-gov  254817   Some-college             10
# 222     90            Private   51744        HS-grad              9
# 244     38            Private  179488   Some-college             10
# 248     40            Private  207578     Assoc-acdm             12
# 321     43            Private   50356   Some-college             10
# 327     43            Private  187728   Some-college             10
# 363     43            Private  174575      Bachelors             13
# 381     46            Private  214955        5th-6th              3
# 387     44            Private  162028   Some-college             10
# 404     28            Private  166481        7th-8th              4
# 405     41            Private  445382        Masters             14
# 408     28                  ?  123147   Some-college             10
# 426     36        Federal-gov  255191        Masters             14
# 434     27            Private  116358   Some-college             10
# 468     49            Private  192776        Masters             14
# 510     49            Private  141944      Assoc-voc             11
# ...    ...                ...     ...            ...            ...
# 32013   61            Private  179743        HS-grad              9
# 32020   21            Private  211968   Some-college             10
# 32035   40            Private  566537      Preschool              1
# 32092   39            Private   30529      Bachelors             13
# 32131   48            Private  109814    Prof-school             15
# 32135   48            Private  175070        HS-grad              9
# 32138   50       Self-emp-inc  121441           11th              7
# 32147   50   Self-emp-not-inc  240922     Assoc-acdm             12
# 32159   46            Private  155933      Bachelors             13
# 32216   45            Private  265097        HS-grad              9
# 32218   37            Private  186009        HS-grad              9
# 32221   37   Self-emp-not-inc  162834        HS-grad              9
# 32230   47       Self-emp-inc  102308    Prof-school             15
# 32250   43            Private  409922      Bachelors             13
# 32254   31            Private  251659   Some-college             10
# 32264   32            Private  260954           11th              7
# 32266   47          Local-gov  324791        Masters             14
# 32267   31            Private  183801        Masters             14
# 32270   60            Private  127084        HS-grad              9
# 32301   65          Local-gov  103153        7th-8th              4
# 32307   42       Self-emp-inc  191196      Bachelors             13
# 32311   54            Private  161691        Masters             14
# 32393   43            Private  191712      Bachelors             13
# 32400   53          Local-gov  186303   Some-college             10
# 32416   33            Private  191335     Assoc-acdm             12
# 32441   53            Private  304504   Some-college             10
# 32443   18            Private   41381        HS-grad              9
# 32445   61            Private  190682        HS-grad              9
# 32458   36            Private  237943      Bachelors             13
# 32500   34            Private   60567           11th              7
#
#               marital-status          occupation     relationship  \
# 23        Married-civ-spouse    Transport-moving          Husband
# 32                  Divorced     Exec-managerial        Own-child
# 52        Married-civ-spouse      Prof-specialty             Wife
# 93        Married-civ-spouse               Sales             Wife
# 96        Married-civ-spouse      Prof-specialty          Husband
# 112       Married-civ-spouse       Other-service          Husband
# 126            Never-married        Adm-clerical        Own-child
# 131            Never-married       Other-service    Not-in-family
# 143            Never-married      Prof-specialty    Not-in-family
# 148       Married-civ-spouse        Craft-repair          Husband
# 157                Separated               Sales        Unmarried
# 170            Never-married       Other-service    Not-in-family
# 172       Married-civ-spouse               Sales          Husband
# 200            Never-married      Prof-specialty    Not-in-family
# 203            Never-married      Prof-specialty    Not-in-family
# 222            Never-married       Other-service    Not-in-family
# 244                 Divorced        Craft-repair    Not-in-family
# 248       Married-civ-spouse        Tech-support          Husband
# 321       Married-civ-spouse        Craft-repair          Husband
# 327       Married-civ-spouse      Prof-specialty             Wife
# 363                 Divorced     Exec-managerial    Not-in-family
# 381                 Divorced        Craft-repair    Not-in-family
# 387       Married-civ-spouse        Adm-clerical             Wife
# 404       Married-civ-spouse   Handlers-cleaners          Husband
# 405       Married-civ-spouse     Exec-managerial          Husband
# 408       Married-civ-spouse                   ?             Wife
# 426            Never-married      Prof-specialty    Not-in-family
# 434            Never-married        Craft-repair        Own-child
# 468       Married-civ-spouse     Exec-managerial          Husband
# 510    Married-spouse-absent   Handlers-cleaners        Unmarried
# ...                      ...                 ...              ...
# 32013     Married-civ-spouse        Craft-repair          Husband
# 32020          Never-married               Sales        Own-child
# 32035     Married-civ-spouse       Other-service          Husband
# 32092     Married-civ-spouse     Exec-managerial          Husband
# 32131     Married-civ-spouse      Prof-specialty          Husband
# 32135               Divorced     Exec-managerial    Not-in-family
# 32138          Never-married     Exec-managerial   Other-relative
# 32147          Never-married               Sales    Not-in-family
# 32159          Never-married   Machine-op-inspct    Not-in-family
# 32216     Married-civ-spouse       Other-service          Husband
# 32218     Married-civ-spouse    Transport-moving          Husband
# 32221     Married-civ-spouse               Sales          Husband
# 32230     Married-civ-spouse      Prof-specialty          Husband
# 32250     Married-civ-spouse     Exec-managerial          Husband
# 32254     Married-civ-spouse       Other-service          Husband
# 32264     Married-civ-spouse        Craft-repair          Husband
# 32266     Married-civ-spouse      Prof-specialty          Husband
# 32267     Married-civ-spouse      Prof-specialty          Husband
# 32270     Married-civ-spouse     Protective-serv          Husband
# 32301     Married-civ-spouse     Exec-managerial          Husband
# 32307     Married-civ-spouse     Exec-managerial          Husband
# 32311               Divorced      Prof-specialty    Not-in-family
# 32393          Never-married        Adm-clerical    Not-in-family
# 32400     Married-civ-spouse     Protective-serv          Husband
# 32416     Married-civ-spouse        Craft-repair          Husband
# 32441     Married-civ-spouse    Transport-moving          Husband
# 32443          Never-married               Sales        Own-child
# 32445                Widowed        Craft-repair    Not-in-family
# 32458     Married-civ-spouse      Prof-specialty          Husband
# 32500               Divorced    Transport-moving        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 23                   White     Male             0          2042
# 32                   White     Male             0          1408
# 52                   White   Female             0          1902
# 93      Asian-Pac-Islander   Female             0          1573
# 96                   White     Male             0          1902
# 112                  White     Male             0          1887
# 126                  White   Female             0          1719
# 131                  White   Female             0          1762
# 143                  White   Female             0          1564
# 148                  White     Male             0          2179
# 157                  Black     Male             0          1816
# 170                  White     Male             0          1980
# 172                  White     Male             0          1977
# 200                  White   Female             0          1876
# 203                  White   Female             0          1340
# 222                  Black     Male             0          2206
# 244                  White     Male             0          1741
# 248                  White     Male             0          1977
# 321                  White     Male             0          1485
# 327                  White   Female             0          1887
# 363                  White     Male             0          1564
# 381                  White   Female             0          2339
# 387                  White   Female             0          2415
# 404                  Other     Male             0          2179
# 405                  White     Male             0          1977
# 408                  White   Female             0          1887
# 426                  White     Male             0          1408
# 434     Asian-Pac-Islander     Male             0          1980
# 468                  White     Male             0          1977
# 510                  White     Male             0          1380
# ...                    ...      ...           ...           ...
# 32013                White     Male             0          2051
# 32020                White   Female             0          1762
# 32035                White     Male             0          1672
# 32092                White     Male             0          1887
# 32131                White     Male             0          1977
# 32135                White   Female             0          2258
# 32138                White     Male             0          2444
# 32147                White   Female             0          1408
# 32159                White   Female             0          1602
# 32216                White     Male             0          1902
# 32218                White     Male             0          1672
# 32221                White     Male             0          1902
# 32230                White     Male             0          2415
# 32250                White     Male             0          1977
# 32254   Asian-Pac-Islander     Male             0          1485
# 32264                White     Male             0          2042
# 32266                White     Male             0          1887
# 32267                White     Male             0          1902
# 32270                White     Male             0          2042
# 32301                White     Male             0          1411
# 32307                White     Male             0          1977
# 32311                White   Female             0          2559
# 32393                White     Male             0          1741
# 32400                White     Male             0          1887
# 32416                White     Male             0          1902
# 32441                White     Male             0          1887
# 32443                White   Female             0          1602
# 32445                Black   Female             0          1669
# 32458                White     Male             0          1977
# 32500                White     Male             0           880
#
#        hours-per-week  native-country  Salary
# 23                 40   United-States   <=50K
# 32                 40   United-States   <=50K
# 52                 60        Honduras    >50K
# 93                 35               ?   <=50K
# 96                 60   United-States    >50K
# 112                50          Canada    >50K
# 126                28   United-States   <=50K
# 131                40   United-States   <=50K
# 143                40   United-States    >50K
# 148                40   United-States   <=50K
# 157                 2   United-States   <=50K
# 170                40   United-States   <=50K
# 172                40   United-States    >50K
# 200                40   United-States   <=50K
# 203                40   United-States   <=50K
# 222                40   United-States   <=50K
# 244                40   United-States   <=50K
# 248                60   United-States    >50K
# 321                50   United-States   <=50K
# 327                50   United-States    >50K
# 363                45   United-States    >50K
# 381                45   United-States   <=50K
# 387                 6   United-States    >50K
# 404                40     Puerto-Rico   <=50K
# 405                65   United-States    >50K
# 408                40   United-States    >50K
# 426                40   United-States   <=50K
# 434                40     Philippines   <=50K
# 468                45   United-States    >50K
# 510                42   United-States   <=50K
# ...               ...             ...     ...
# 32013              20   United-States   <=50K
# 32020              28   United-States   <=50K
# 32035              40          Mexico   <=50K
# 32092              40   United-States    >50K
# 32131              45   United-States    >50K
# 32135              40   United-States    >50K
# 32138              40   United-States    >50K
# 32147               5   United-States   <=50K
# 32159               8   United-States   <=50K
# 32216              40   United-States    >50K
# 32218              60   United-States   <=50K
# 32221              45   United-States    >50K
# 32230              45   United-States    >50K
# 32250              50   United-States    >50K
# 32254              55               ?    >50K
# 32264              30   United-States   <=50K
# 32266              50   United-States    >50K
# 32267              43   United-States    >50K
# 32270              34   United-States   <=50K
# 32301              40   United-States   <=50K
# 32307              60               ?    >50K
# 32311              40   United-States    >50K
# 32393              40   United-States   <=50K
# 32400              40   United-States    >50K
# 32416              50   United-States    >50K
# 32441              45   United-States    >50K
# 32443              20   United-States   <=50K
# 32445              50   United-States   <=50K
# 32458              45   United-States    >50K
# 32500              60   United-States   <=50K
#
# [1519 rows x 15 columns]

# %%
adult.iloc[0]['sex']
# Out:
# ' Male'

# %%
titanic = pd.read_csv('data/titanic-train.csv')

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic[titanic.Age.notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 34                             Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 37                            Cann, Mr. Ernest Charles    male  21.0      0
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 857                             Daly, Mr. Peter Denis     male  51.0      0
# 858              Baclini, Mrs. Solomon (Latifa Qurban)  female  24.0      0
# 860                            Hansen, Mr. Claus Peter    male  41.0      2
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 18       0            345763   18.0000          NaN        S
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 27       2             19950  263.0000  C23 C25 C27        S
# 30       0          PC 17601   27.7208          NaN        C
# 33       0        C.A. 24579   10.5000          NaN        S
# 34       0          PC 17604   82.1708          NaN        C
# 35       0            113789   52.0000          NaN        S
# 37       0        A./5. 2152    8.0500          NaN        S
# 38       0            345764   18.0000          NaN        S
# ..     ...               ...       ...          ...      ...
# 856      1             36928  164.8667          NaN        S
# 857      0            113055   26.5500          E17        S
# 858      3              2666   19.2583          NaN        C
# 860      0            350026   14.1083          NaN        S
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [714 rows x 12 columns]

# %%
titanic[titanic.Age.notnull()].Age.median()
# Out:
# 28.0

# %%
#fill missing age
titanic.Age = titanic.Age.fillna(28)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
titanic.Name.str.len().max()
# Out:
# 82

# %%
titanic[titanic.Name.str.len() == 82]
# Out:
#      PassengerId  Survived  Pclass  \
# 307          308         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0      1
#
#      Parch    Ticket   Fare Cabin Embarked
# 307      0  PC 17758  108.9   C65        C

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Fare.max()
# Out:
# 512.3292

# %%
titanic[titanic.Fare == 512.3292]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
titanic[titanic.Fare == 512.3292]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
