# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/house_rental_data.csv')
df.head()
# Out:
#    Unnamed: 0      Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  \
# 0           1  1177.698      2           7        2            2         2
# 1           2  2134.800      5           7        4            2         2
# 2           3  1138.560      5           7        2            2         1
# 3           4  1458.780      2           7        3            2         2
# 4           5   967.776     11          14        3            2         2
#
#    Price
# 0  62000
# 1  78000
# 2  58000
# 3  45000
# 4  45000

# %%
plt.plot(df.Floor, df.Price)
#non linear

# %%
plt.plot(df.Sqft, df.Price)
#kindof linear

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
X = np.linspace(0,1,1000).reshape(-1,1)

# %%
X
# Out:
# array([[0.        ],
#        [0.001001  ],
#        [0.002002  ],
#        [0.003003  ],
#        [0.004004  ],
#        [0.00500501],
#        [0.00600601],
#        [0.00700701],
#        [0.00800801],
#        [0.00900901],
#        [0.01001001],
#        [0.01101101],
#        [0.01201201],
#        [0.01301301],
#        [0.01401401],
#        [0.01501502],
#        [0.01601602],
#        [0.01701702],
#        [0.01801802],
#        [0.01901902],
#        [0.02002002],
#        [0.02102102],
#        [0.02202202],
#        [0.02302302],
#        [0.02402402],
#        [0.02502503],
#        [0.02602603],
#        [0.02702703],
#        [0.02802803],
#        [0.02902903],
#        [0.03003003],
#        [0.03103103],
#        [0.03203203],
#        [0.03303303],
#        [0.03403403],
#        [0.03503504],
#        [0.03603604],
#        [0.03703704],
#        [0.03803804],
#        [0.03903904],
#        [0.04004004],
#        [0.04104104],
#        [0.04204204],
# ...

# %%
Y = 5*X + 10

# %%
#find 5 and 10 by passing X and Y
lr.fit(X,Y)
#train model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.coef_
#5 is the slope, 10 is the intercept
# Out:
# array([[5.]])

# %%
lr.intercept_
# Out:
# array([10.])

# %%
plt.plot(X,Y)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(np.linspace(0,1,1000))
# Out:
# numpy.ndarray

# %%
loss = y- y1
cost = 1/m Sigma((y-y1)square)
=> Root mean Sqare => RMS
Gradient discent => Process to find minumum cost
